# %%
from whitebox_workflows import WbEnvironment
import numpy as np
import math
from operator import itemgetter, attrgetter

# %%
wbe = WbEnvironment()

# %%
dem = wbe.read_raster(r"C:\Work\imWEBs\BRC\model\BRC\Watershed\input\dem.dep")
dem

# %%
dem.configs

# %%
dem.configs.rows
# Out:
# 1040

# %%
dem.configs.epsg_code
# Out:
# 0

# %%
dem.configs.nodata
# Out:
# -32768.0

# %%
dem.configs.north
# Out:
# 5577620.0300033325

# %%
def ValidateRaster(standardRaster:str, checkRaster:str):
    """Check if the raster have same size as the standard raster """
    wbe = WbEnvironment()
    standar_raster_config = wbe.read_raster(standardRaster).configs
    check_raster_config = wbe.read_raster(checkRaster).configs

    return standar_raster_config.rows == check_raster_config.rows and \
        standar_raster_config.columns == check_raster_config.columns and \
        standar_raster_config.resolution_x == check_raster_config.resolution_x and \
        standar_raster_config.resolution_y == check_raster_config.resolution_y and \
        standar_raster_config.east == check_raster_config.east and \
        standar_raster_config.west == check_raster_config.west
