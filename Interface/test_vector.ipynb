# %%
from whitebox_workflows import WbEnvironment, Raster, Vector

# %%
shapefile = r"C:\Work\imWEBs\test\test_model\watershed\input\field.shp"

wbe = WbEnvironment()
vector = wbe.read_vector(shapefile)

# %%
vector[0]

# %%
vector.attributes
