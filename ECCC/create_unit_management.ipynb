# %%
import geopandas as gpd

# %%
field_shp_path = r"D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\STC2021\field.shp"
subbasin_shap_path = r"D:\imWEBs\STC\model\STC-Catchabasin-Reservoir-Separated\Watershed\Output\subbasin.shp"
feedlot_shp_path = r"D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\STC2021\cattle_yard.shp"
wetland_shp_path = r"D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\STC2021\wetland.shp"
gww_fs_rb_shp_path = r"D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\STC2021\STC_GWW_FS_RB\gww_fs_rb_10m.shp"

# %%
dfdiff1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30104/1858229009.py in <module>
# ----> 1 dfdiff1
#
# NameError: name 'dfdiff1' is not defined

# %%
field_df = gpd.read_file(field_shp_path)
subbasin_df = gpd.read_file(subbasin_shap_path)

unit_management_df = gpd.overlay(field_df,subbasin_df, how='union')
unit_management_df
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30104/3065430077.py in <module>
#       2 subbasin_df = gpd.read_file(subbasin_shap_path)
#       3
# ----> 4 unit_management_df = gpd.overlay(field_df,subbasin_df, how='union')
#       5 unit_management_df
#
# ~\AppData\Roaming\Python\Python37\site-packages\geopandas\tools\overlay.py in overlay(df1, df2, how, keep_geom_type, make_valid)
#     294             result = _overlay_symmetric_diff(df1, df2)
#     295         elif how == "union":
# --> 296             result = _overlay_union(df1, df2)
#     297         elif how == "identity":
#     298             dfunion = _overlay_union(df1, df2)
#
# ~\AppData\Roaming\Python\Python37\site-packages\geopandas\tools\overlay.py in _overlay_union(df1, df2)
#     129     """
#     130     dfinter = _overlay_intersection(df1, df2)
# ...
