# %% [markdown]
# #run conversion program to generate parameter_subarea.db3
#
# D:\git\imWEBs\imWEBs\ImwebsInputTool\ImwebsInputTool\ImwebsSubarea.Input.CLI\bin\Debug\netcoreapp3.1\ImwebsSubarea.Input.CLI.exe base-conversion-all
# D:\git\imWEBs\imWEBs\ImwebsInputTool\ImwebsInputTool\ImwebsSubarea.Input.CLI\bin\Debug\netcoreapp3.1\ImwebsSubarea.Input.CLI.exe bmp-conversion-all

# %% [markdown]
# #update wetland_Parameter set OperationYear = 0 where ClassType <> 'DrainedLost'
#
# #update reach_bmp set Scenario = 1

# %%
#add crop/fertilizer/tillage for wetland field 1000 and 1001 to copy from field 1
