# %% [markdown]
# generate riparian buffer/feed lot drainage, parts and parameter table with VFSandRBS function
#
#                     VFSandRBS vfs = new VFSandRBS();
#                     String[] temp_args = new String[11];
#                     String dir = "D:\\imWEBs\\STC\\model\\STC\\watershed\\Output\\";
#                     String outDir = "D:\\git\\imWEBs\\IMWEBsInterface\\resources\\DemoDatasets\\STC2021\\STC_GWW_FS_RB\\";
#
#                     //BRC
#                     dir = "D:\\imWEBs\\BRC\\model\\BRC\\Watershed\\Output\\";
#                     outDir = "D:\\git\\imWEBs\\IMWEBsInterface\\resources\\DemoDatasets\\BRC2021\\SubArea_Buffer_5m\\output\\";
#
#
#                     if(isFeedlot)
#                         outDir = "D:\\git\\imWEBs\\IMWEBsInterface\\resources\\DemoDatasets\\STC2021\\Feedlot\\";
#                     temp_args[0] = dir + "flow_dir.dep";//this.getFlowDirD8FinalRaster();
#                     temp_args[1] = outDir + "buffer_drainage.dep";//this.getVegetationFilterStripDrainageRaster();
#
#                     temp_args[2] = outDir + "stc_gww_fs_rb.dep";//this.getVegetationFilterStripRaster();
#                     if(isFeedlot){
#                         temp_args[1] = outDir + "feedlot_drainage.dep";//this.getVegetationFilterStripDrainageRaster();
#                         temp_args[2] = outDir + "cattle_yard.dep";//this.getVegetationFilterStripRaster();
#                     }
#                     //BRC
#                     temp_args[2] = outDir + "field_strip.dep";
#
#
#                     temp_args[3] = dir + "subbasin.dep";//this.getSubbasinRaster();
#                     temp_args[4] = dir + "slope.dep";//this.getSlopeDegRaster();
#                     temp_args[5] = dir + "soil.dep";//this.getSoilRaster();
#                     temp_args[6] = dir + "landuse.dep";//this.getLanduseRaster();
#                     temp_args[7] = "ripa_buffer_table";//tableName;
#                     temp_args[8] = outDir + "buffer_parts.dep";//this.getVegetationFilterStripPartRaster();
#                     if(isFeedlot){
#                         temp_args[8] = outDir + "feedlot_parts.dep";//this.getVegetationFilterStripPartRaster();
#                     }
#                     temp_args[9] = "10.0";// width
#                     if(isFeedlot){
#                         temp_args[9] = "0";// width
#                     }
#                     temp_args[10] = BMPType.RIBUF.toString();// width
#
#                     vfs.setArgs(temp_args);
#                     vfs.run();
# //
#                     // export to CSV
#                     if(isFeedlot)
#                         vfs.getOutputTable().exportCSV(outDir + "feedlot_parameter.csv");
#                     else
#                         vfs.getOutputTable().exportCSV(outDir + "buffer_parameter.csv");

# %% [markdown]
# add buffer_drainage and buffer_parts to parameter.h5 and export to txt file for next step
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_5m\output\buffer_drainage.dep" "D:\imWEBs\BRC\model\Buffer_5m\Buffer_5m\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_5m\output\buffer_parts.dep" "D:\imWEBs\BRC\model\Buffer_5m\Buffer_5m\parameter.h5"
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_15m\output\buffer_drainage.dep" "D:\imWEBs\BRC\model\Buffer_15m\Buffer_15m\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_15m\output\buffer_parts.dep" "D:\imWEBs\BRC\model\Buffer_15m\Buffer_15m\parameter.h5"
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_30m\output\buffer_drainage.dep" "D:\imWEBs\BRC\model\Buffer_30m\Buffer_30m\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_30m\output\buffer_parts.dep" "D:\imWEBs\BRC\model\Buffer_30m\Buffer_30m\parameter.h5"

# %% [markdown]
# Export the buffer_drainage and buffer_parts to text file for next step
