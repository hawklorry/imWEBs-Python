# %% [markdown]
# Then we will need to run the IMWEBsHDF5Util.jar save-raster-to-h5 to add the subarea.dep to parameter.h5 and then export to text file: CellSubarea.csv
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_NoBuffer\output\subarea.dep" "D:\imWEBs\BRC\model\Existing\Existing\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Enhancement_5m\output\subarea.dep" "D:\imWEBs\BRC\model\Enhancement_5m\Enhancement_5m\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Enhancement_15m\output\subarea.dep" "D:\imWEBs\BRC\model\Enhancement_15m\Enhancement_15m\parameter.h5"
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Enhancement_30m\output\subarea.dep" "D:\imWEBs\BRC\model\Enhancement_30m\Enhancement_30m\parameter.h5"
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_5m\output\subarea.dep" "D:\imWEBs\BRC\model\Buffer_5m\Buffer_5m\parameter.h5"
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_15m\output\subarea.dep" "D:\imWEBs\BRC\model\Buffer_15m\Buffer_15m\parameter.h5"
#
#
# java -D"java.library.path"="D:\imWEBs\06.Document\Files_tools\03.Tools\03.Tools\01.IMWEBsHDF5Util\IMWEBsHDF5Util\lib" -jar .\IMWEBsHDF5Util.jar save-raster-to-h5 "D:\git\imWEBs\IMWEBsInterface\resources\DemoDatasets\BRC2021\SubArea_Buffer_30m\output\subarea.dep" "D:\imWEBs\BRC\model\Buffer_30m\Buffer_30m\parameter.h5"

# %% [markdown]
# Step2: Export cell parameters to CellSubArea.csv
