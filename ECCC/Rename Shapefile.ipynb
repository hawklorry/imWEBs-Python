# %%
import geopandas as gpd
import numpy as np

# %%
shp_path = r"D:\imWEBs\STC\STC-Landuse-Data\Landuse_1991-2000\projected"

# %%
out_path = r"D:\imWEBs\STC\STC-Landuse-Data\Landuse_1991-2000\renamed"

# %%
years = np.arange(start = 1991, stop = 2001, step = 1)
years
# Out:
# array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000])

# %%
for y in years:
    shp = gpd.read_file(f"{shp_path}/{y}.shp")
    shp.to_file(f"{out_path}/land{y}_by_land_id.shp")
