# %%
import pandas as pd

# %%
csv = pd.read_csv(r"D:\Richmond\calibration\output\2020-12-21.csv")

# %%
csv.columns
# Out:
# Index(['time', 'Hamilton_Community_Center', 'time.1', 'Richmond_City_Hall',
#        'time.2', 'Richmond_Fire_Hall_#2', 'time.3', 'Richmond_Fire_Hall_#7',
#        'time.4', 'Richmond_Ice_Center', 'time.5', 'RTU1', 'time.6', 'RTU109',
#        'time.7', 'RTU114', 'time.8', 'RTU116', 'time.9', 'RTU134', 'time.10',
#        'RTU141', 'time.11', 'RTU158', 'time.12', 'RTU170', 'time.13', 'RTU180',
#        'time.14', 'RTU206', 'time.15', 'RTU25', 'time.16', 'RTU3', 'time.17',
#        'RTU45', 'time.18', 'RTU47', 'time.19', 'RTU5', 'time.20', 'RTU66',
#        'time.21', 'RTU74', 'time.22', 'RTU79', 'time.23', 'RTU89', 'time.24',
#        'RTU9', 'time.25', 'RTU92', 'Unnamed: 52'],
#       dtype='object')

# %%
column = csv['Hamilton_Community_Center']

# %%
column
# Out:
# 0       0.00
# 1       0.25
# 2       0.50
# 3       1.25
# 4       1.00
#         ...
# 1760     NaN
# 1761     NaN
# 1762     NaN
# 1763     NaN
# 1764     NaN
# Name: Hamilton_Community_Center, Length: 1765, dtype: float64

# %%
column.max()
# Out:
# 4.75

# %%
column.argmax()
# Out:
# 8

# %%
column.iloc[8]
# Out:
# 4.75
