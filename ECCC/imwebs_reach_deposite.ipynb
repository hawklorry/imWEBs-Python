# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
field_shp = r"D:\imWEBs\STC\STC-Landuse-Data\field\unit_management_from_raster_dissolved.shp"
grazing_management_csv = r"D:\imWEBs\STC\STC-Landuse-Data\Processed\grazing_management.csv"
fertilizer_parameter_csv = r"D:\imWEBs\STC\STC-Landuse-Data\Processed\lookups\fertilizer_parameter.csv"
livestock_parameter_csv = r"D:\imWEBs\STC\STC-Landuse-Data\Processed\lookups\lvestock_parameter.csv"

# %%
#read grazing management table
df_grazing = pd.read_csv(grazing_management_csv)

#add field area from shapefile 
field_shp_df = gpd.read_file(field_shp)
field_shp_df['Area'] = field_shp_df.geometry.area / 10000
field_shp_df = field_shp_df.rename(columns={"LAND_ID": "Location"})
reach_deposit_df = df_grazing.merge(field_shp_df, how = 'inner', on = 'Location')
reach_deposit_df.drop('geometry', inplace=True, axis=1)
reach_deposit_df
# Out:
#       Scenario  Location  Year  GraMon  GraDay  Days  Ani_ID  Ani_adult  \
# 0            1      1162     1       5       1   180       2        100
# 1            1      1162     2       5       1   180       2        100
# 2            1      1162     3       5       1   180       2        100
# 3            1      1162     4       5       1   180       2        100
# 4            1      1162     5       5       1   180       2        100
# ...        ...       ...   ...     ...     ...   ...     ...        ...
# 4602         1      6905    30       5       1   180       2        100
# 4603         1      7006    30       5       1   180       2        100
# 4604         1      7071    30       5       1   180       2        100
# 4605         1      7084    30       5       1   180       2        100
# 4606         1      7649    30       5       1   180       2        100
#
#       GR_Density  DayFra  Source  SourceID  Dugout_ID  Access  Fencing  \
# ...

# %%
np.repeat(reach_deposit_df.iloc[[0]].values,180,axis=0)
# Out:
# array([[1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00],
#        [1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00],
#        [1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00],
#        ...,
#        [1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00],
#        [1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00],
#        [1.000e+00, 1.162e+03, 1.000e+00, ..., 2.000e-02, 3.000e-01,
#         1.260e+00]])

# %%
reach_deposit_df.iloc[0].Days
# Out:
# 180.0

# %%
def get_month_day(year, month, day, adddays):

# %%
df = pd.DataFrame(np.repeat(reach_deposit_df.iloc[[0]].values,reach_deposit_df.iloc[0].Days,axis=0),columns=reach_deposit_df.columns)
df["Month"] =
# Out:
#      Scenario  Location  Year  GraMon  GraDay   Days  Ani_ID  Ani_adult  \
# 0         1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 1         1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 2         1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 3         1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 4         1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# ..        ...       ...   ...     ...     ...    ...     ...        ...
# 175       1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 176       1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 177       1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 178       1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
# 179       1.0    1162.0   1.0     5.0     1.0  180.0     2.0      100.0
#
#      GR_Density  DayFra  Source  SourceID  Dugout_ID  Access  Fencing  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=180, step=1)

# %%
#repeat each row for each grazing day

for index in reach_deposit_df.index:
    reach_deposit_df.iloc[index].values

reach_deposit_df

# %%
one_year_df = reach_deposit_df[reach_deposit_df["Year"] == 3]
one_year_pivot = pd.pivot_table(one_year_df, values="Area", index="SourceID", aggfunc=np.sum)
one_year_pivot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20868/403429757.py in <module>
#       1 one_year_df = reach_deposit_df[reach_deposit_df["Year"] == 3]
# ----> 2 one_year_pivot = pd.pivot_table(one_year_df, values="Area", index="SourceID", aggfunc=np.sum)
#       3 one_year_pivot
#
# NameError: name 'np' is not defined
