# %% [markdown]
# Subarea shapefile is now generated.
#
# We will need to manually generate the identity layer of subarea and landuse/soil. It could be done with code but it's quite slow for soil.
#
# The resulting file name must be subarea_soil.shp and subarea_landuse.shp
