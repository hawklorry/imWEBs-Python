# %% [markdown]
# #
#
# **BMP Type**
#
# 1.  Reach BMP
#
# 2.  Areal Structure BMP
#
# 3.  Areal non-structure BMP
#
# 4.  Manure Adjustment
#
# |  |  |  |  |
# |:---------------:|:-------------------:|:---------------:|:---------------:|
# | **ID** | **Name** | **Type** | **Code** |
# | 1 | [Point source](01_point_source.qmd) | 1 | PTSR |
# | 2 | Stream flow diversion | 1 | SFDV |
# | 3 | [Reservoir](03_reservoir.qmd) | 1 | RESV |
# | 4 | Riparian wetland | 1 | RIWET |
# | 5 | [Riparian buffer](05_riparian_buffer.qmd) | 2 | RIBUF |
# | 6 | [Grass waterway](06_grassed_waterway.qmd) | 1 | GWW |
# | 7 | [Vegetation filter strip](07_vegetation_filter_strip.qmd) | 2 | VFST |
# | 8 | Pond | 2 | POND |
# | 9 | [Isolated wetland](09_wetland.qmd) | 1 | ISWET |
# | 10 | Terrace | 2 | TERR |
# | 11 | Overland flow diversion | 2 | OLFDV |
# | 12 | [Crop management](12_crop_management.qmd) | 3 | CRPMG |
# | 13 | Residual management | 3 | RSDMG |
# | 14 | [Tillage management](12_crop_management.qmd) | 3 | TILMG |
# | 15 | [Fertilizer management](12_crop_management.qmd) | 3 | FERMG |
# | 16 | [Grazing management](12_crop_management.qmd) | 3 | GRAMG |
# | 17 | Pesticide management | 3 | PESMG |
# | 18 | Irrigation management | 3 | IRRMG |
# | 19 | [Tile drain management](19_tiledrain_qmd) | 2 | TLDMG |
# | 20 | Urban management | 2 | URBMG |
# | 21 | [Manure incorporation with 48h](21_26_manure_adjustment.qmd) | 4 | MI48H |
# | 22 | [Manure application setback](21_26_manure_adjustment.qmd) | 4 | MASB |
# | 23 | [No application on snow](21_26_manure_adjustment.qmd) | 4 | NAOS |
# | 24 | [Spring application rather than fall application](21_26_manure_adjustment.qmd) | 4 | SAFA |
# | 25 | [Application based on soil nitrogen limit](21_26_manure_adjustment.qmd) | 4 | ASNL |
# | 26 | [Application based on soil phosphorous limit](21_26_manure_adjustment.qmd) | 4 | ASPL |
# | 27 | [Manure storage capacity and design](27_manure_storage.qmd) | 3 | MSCD |
# | 28 | [Manure catch basin/impondment](28_manure_catch_basin.qmd) | 1 | MCBI |
# | 29 | [Manure feedlot](29_manure_feedlot.qmd) | 3 | FDLT |
# | 30 | [Marginal crop management](30_31_32_marginal_crop_land) | 3 | MCLCM |
# | 31 | [Marginal fertilizer management](30_31_32_marginal_crop_land) | 3 | MCLFM |
# | 32 | [Marginal tillage management](30_31_32_marginal_crop_land) | 3 | MCLTM |
# | 33 | Wintering site management | 3 | WSMG |
# | 34 | [Pasture crop management](34_35_36_pasture_crop_land.qmd) | 3 | PSCM |
# | 35 | [Pasture fertilizer management](34_35_36_pasture_crop_land.qmd) | 3 | PSFM |
# | 36 | [Pasture tillage management](34_35_36_pasture_crop_land.qmd) | 3 | PSTM |
# | 37 | Pasture grazing management | 3 | PSGM |
# | 38 | Dugout | 2 | DGOT |
# | 39 | [Off site watering](39_offsite_watering.qmd) | 0 | OFSW |
# | 40 | Managed access including fencing | 1 | MAIF |
# | 41 | [Water and sediment control basin](41_wascob.qmd) | 2 | WSCB |
# | 42 | Water Use | 1 | WAUS |
