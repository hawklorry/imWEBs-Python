# %% [markdown]
# #
#
# # 06 Grassed Waterway
#
# ## Location
#
# The location of the grassed waterway is defined in **\[reach_bmp\]**
# section using **grass_waterway_shapefile**. One example is given below.
# The shapefile must be **polyline** type.
#
# *\[reach_bmp\]*
#
# *grass_waterway_shapefile = GWW.shp*
